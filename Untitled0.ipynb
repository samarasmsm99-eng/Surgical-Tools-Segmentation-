# %%
# تنصيب مكتبة التراليتكس الخاصة بـ YOLO
# !pip install ultralytics

# استدعاء المكتبة وفحص بيئة العمل وكارت الشاشة
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.9/112.6 GB disk)

# %%
# تنصيب مكتبة روبوفلو لسحب الصور الجاهزة
# !pip install roboflow

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CIEKO4QHM86YuTKh3PQ7")
project = rf.workspace("comp-5900").project("cholec-seg-8k-instance")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cholec-seg-8k-instance-1 in yolov8-obb:: 100%|██████████| 16166/16166 [00:05<00:00, 2870.67it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CIEKO4QHM86YuTKh3PQ7")
project = rf.workspace("comp-5900").project("cholec-seg-8k-instance")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import yaml

# مسار ملف الخريطة
yaml_path = '/content/cholec-seg-8k-instance-1/data.yaml'

# قراءة الملف الحالي
with open(yaml_path, 'r') as file:
    data = yaml.safe_load(file)

# تحديث المسارات لتطابق مجلدات الكولاب بالضبط
data['train'] = '/content/cholec-seg-8k-instance-1/train/images'
data['val'] = '/content/cholec-seg-8k-instance-1/valid/images'
if 'test' in data:
    data['test'] = '/content/cholec-seg-8k-instance-1/test/images'

# حفظ الملف بالمسارات الجديدة
with open(yaml_path, 'w') as file:
    yaml.dump(data, file)

print("✅ تم تعديل المسارات بنجاح!")
# Out:
# ✅ تم تعديل المسارات بنجاح!

# %%
from ultralytics import YOLO

# استدعاء نموذج التجزئة
model = YOLO('yolov8n-seg.pt')

# البدء بتدريب النموذج
results = model.train(
    data='/content/cholec-seg-8k-instance-1/data.yaml',
    epochs=15,
    imgsz=640,
    device=0,
    project='Surgical_Tools_Segmentation',
    name='baseline_run'
)
# Out:
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
